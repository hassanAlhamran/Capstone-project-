# %%
import pandas as pd

# %%
df=pd.read_csv("traffic_accidents123.csv")

# %%
df.isnull().sum()
# Out:
# crash_date                       0
# traffic_control_device           0
# weather_condition                0
# lighting_condition               0
# first_crash_type                 0
# trafficway_type                  0
# alignment                        0
# roadway_surface_cond             0
# road_defect                      0
# crash_type                       0
# intersection_related_i           0
# damage                           0
# prim_contributory_cause          0
# num_units                        0
# most_severe_injury               0
# injuries_total                   0
# injuries_fatal                   0
# injuries_incapacitating          0
# injuries_non_incapacitating      0
# injuries_reported_not_evident    0
# injuries_no_indication           0
# crash_hour                       0
# crash_day_of_week                0
# crash_month                      0
# dtype: int64

# %%
import pandas as pd


df = pd.read_csv("traffic_accidents123.csv")


df['crash_date'] = pd.to_datetime(df['crash_date'], errors='coerce', infer_datetime_format=True)


df['crash_only_date'] = df['crash_date'].dt.date
df['crash_only_time'] = df['crash_date'].dt.time


df.to_csv("traffic_accidents_cleaned.csv", index=False)

print("Cleaning complete! File saved as traffic_accidents_cleaned.csv")
df.head()
# Out:
# C:\Users\Windows 10 Pro\AppData\Local\Temp\ipykernel_17196\4384536.py:7: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['crash_date'] = pd.to_datetime(df['crash_date'], errors='coerce', infer_datetime_format=True)
# C:\Users\Windows 10 Pro\AppData\Local\Temp\ipykernel_17196\4384536.py:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['crash_date'] = pd.to_datetime(df['crash_date'], errors='coerce', infer_datetime_format=True)
# Cleaning complete! File saved as traffic_accidents_cleaned.csv
#            crash_date traffic_control_device weather_condition  \
# 0 2023-07-29 13:00:00         TRAFFIC SIGNAL             CLEAR
# ...

# %%
df['crash_date'] = pd.to_datetime(df['crash_date'], errors='coerce', infer_datetime_format=True)


df['crash_date'] = df['crash_date'].dt.date


df['crash_time'] = pd.to_datetime(df['crash_date'], errors='coerce').dt.time


df.to_csv("traffic_accidents_cleaned.csv", index=False)

print(df[['crash_date']].head())
# Out:
# C:\Users\Windows 10 Pro\AppData\Local\Temp\ipykernel_17196\1447034427.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['crash_date'] = pd.to_datetime(df['crash_date'], errors='coerce', infer_datetime_format=True)
#    crash_date
# 0  2023-07-29
# 1  2023-08-13
# 2  2021-12-09
# 3  2023-08-09
# 4  2023-08-19

# %%
import pandas as pd


df = pd.read_csv("traffic_accidents123.csv")

df['crash_date'] = pd.to_datetime(df['crash_date'], errors='coerce')


df['crash_date'] = df['crash_date'].dt.strftime("%m-%d-%Y")


df.to_csv("traffic_accidents_cleaned.csv", index=False)

print(df[['crash_date']].head(10))
# Out:
# C:\Users\Windows 10 Pro\AppData\Local\Temp\ipykernel_17196\3506717748.py:6: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['crash_date'] = pd.to_datetime(df['crash_date'], errors='coerce')
#    crash_date
# 0  07-29-2023
# 1  08-13-2023
# 2  12-09-2021
# 3  08-09-2023
# 4  08-19-2023
# 5  09-06-2023
# 6  12-20-2022
# 7  09-20-2023
# 8  06-04-2018
# 9  09-07-2023

# %%
import pandas as pd


df = pd.read_csv("traffic_accidents123.csv")


df_cleaned = df.drop_duplicates(keep="first")


df_cleaned.to_csv("traffic_accidents_no_duplicates.csv", index=False)

print("All duplicates removed! File saved as 'traffic_accidents_no_duplicates.csv'")
# Out:
# All duplicates removed! File saved as 'traffic_accidents_no_duplicates.csv'

# %%
import pandas as pd


file_path = "traffic_accidents123.csv"
df = pd.read_csv(file_path)
df = df.drop_duplicates()
if "crash_date" in df.columns:
    df["crash_date"] = pd.to_datetime(df["crash_date"], errors="coerce")
    df["crash_date"] = df["crash_date"].dt.strftime("%m-%d-%Y")

if "crash_time" in df.columns:
    df["crash_time"] = pd.to_datetime(df["crash_time"], errors="coerce").dt.strftime("%H:%M:%S")

df = df.fillna({
    "crash_date": "Unknown",
    "crash_time": "Unknown",
    "damage": "UNKNOWN",
    "prim_contributory_cause": "UNKNOWN"
})


cat_cols = [
    "lighting_condition", "first_crash_type", "trafficway_type",
    "alignment", "roadway_surface_cond", "road_defect",
    "crash_type", "intersection_related_i", "damage",
    "prim_contributory_cause", "most_severe_injury"
]
for col in cat_cols:
    if col in df.columns:
        df[col] = df[col].astype(str).str.strip().str.upper()

if set(["injuries_total", "injuries_fatal", "injuries_incapacitating",
        "injuries_non_incapacitating", "injuries_reported_not_evident",
        "injuries_no_indication"]).issubset(df.columns):

    df["injuries_check"] = (
        df["injuries_fatal"] +
        df["injuries_incapacitating"] +
        df["injuries_non_incapacitating"] +
        df["injuries_reported_not_evident"] +
        df["injuries_no_indication"]
    )

   
    df["injury_mismatch"] = df["injuries_total"] != df["injuries_check"]


df.to_csv("traffic_accidents_cleaned.csv", index=False)
print("✅ Cleaning complete! Saved as 'traffic_accidents_cleaned.csv'")
# Out:
# C:\Users\Windows 10 Pro\AppData\Local\Temp\ipykernel_17196\4037573572.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["crash_time"] = pd.to_datetime(df["crash_time"], errors="coerce").dt.strftime("%H:%M:%S")
# ✅ Cleaning complete! Saved as 'traffic_accidents_cleaned.csv'

# %%
df.to_csv("traffic_accidents_cleaned.csv", index=False)

# %%
df = pd.read_csv("traffic_accidents_cleaned.csv")  
print(df.isnull().sum())
print((df.isnull().mean() * 100).round(2))
# Out:
# crash_date                       0
# crash_time                       0
# AM/PM                            1
# lighting_condition               0
# first_crash_type                 0
# trafficway_type                  0
# alignment                        0
# roadway_surface_cond             0
# road_defect                      0
# crash_type                       0
# intersection_related_i           0
# damage                           0
# prim_contributory_cause          0
# num_units                        1
# most_severe_injury               0
# injuries_total                   1
# injuries_fatal                   1
# injuries_incapacitating          1
# injuries_non_incapacitating      1
# injuries_reported_not_evident    1
# injuries_no_indication           1
# crash_hour                       1
# crash_day_of_week                1
# crash_month                      1
# injuries_check                   1
# injury_mismatch                  0
# dtype: int64
# ...

# %%
df = df.dropna()

# %%
df = pd.read_csv("traffic_accidents_cleaned.csv")  
print(df.isnull().sum())
print((df.isnull().mean() * 100).round(2))
# Out:
# crash_date                       0
# crash_time                       0
# AM/PM                            1
# lighting_condition               0
# first_crash_type                 0
# trafficway_type                  0
# alignment                        0
# roadway_surface_cond             0
# road_defect                      0
# crash_type                       0
# intersection_related_i           0
# damage                           0
# prim_contributory_cause          0
# num_units                        1
# most_severe_injury               0
# injuries_total                   1
# injuries_fatal                   1
# injuries_incapacitating          1
# injuries_non_incapacitating      1
# injuries_reported_not_evident    1
# injuries_no_indication           1
# crash_hour                       1
# crash_day_of_week                1
# crash_month                      1
# injuries_check                   1
# injury_mismatch                  0
# dtype: int64
# ...

# %%
cat_cols = ["AM/PM", "prim_contributory_cause", "most_severe_injury"]
df[cat_cols] = df[cat_cols].fillna("UNKNOWN")


num_cols = [
    "num_units", "injuries_total", "injuries_fatal",
    "injuries_incapacitating", "injuries_non_incapacitating",
    "injuries_reported_not_evident", "injuries_no_indication",
    "crash_hour", "crash_day_of_week", "crash_month",
    "injuries_check"
]
df[num_cols] = df[num_cols].fillna(0)

# %%
df = pd.read_csv("traffic_accidents_cleaned.csv")  
print(df.isnull().sum())
print((df.isnull().mean() * 100).round(2))
# Out:
# crash_date                       0
# crash_time                       0
# AM/PM                            1
# lighting_condition               0
# first_crash_type                 0
# trafficway_type                  0
# alignment                        0
# roadway_surface_cond             0
# road_defect                      0
# crash_type                       0
# intersection_related_i           0
# damage                           0
# prim_contributory_cause          0
# num_units                        1
# most_severe_injury               0
# injuries_total                   1
# injuries_fatal                   1
# injuries_incapacitating          1
# injuries_non_incapacitating      1
# injuries_reported_not_evident    1
# injuries_no_indication           1
# crash_hour                       1
# crash_day_of_week                1
# crash_month                      1
# injuries_check                   1
# injury_mismatch                  0
# dtype: int64
# ...

# %%
missing_rows = df[df.isnull().any(axis=1)]
print(missing_rows)
# Out:
#        crash_date crash_time AM/PM lighting_condition first_crash_type  \
# 209265    Unknown    Unknown   NaN                NAN              NAN
#
#        trafficway_type alignment roadway_surface_cond road_defect crash_type  \
# 209265             NAN       NAN                  NAN         NAN        NAN
#
#         ... injuries_fatal injuries_incapacitating  \
# 209265  ...            NaN                     NaN
#
#        injuries_non_incapacitating  injuries_reported_not_evident  \
# 209265                         NaN                            NaN
#
#        injuries_no_indication  crash_hour  crash_day_of_week  crash_month  \
# 209265                    NaN         NaN                NaN          NaN
#
#         injuries_check  injury_mismatch
# 209265             NaN             True
#
# [1 rows x 26 columns]

# %%
df = df.fillna({
    "AM/PM": "UNKNOWN",
    "prim_contributory_cause": "UNKNOWN",
    "most_severe_injury": "UNKNOWN",
    "num_units": 0,
    "injuries_total": 0,
    "injuries_fatal": 0,
    "injuries_incapacitating": 0,
    "injuries_non_incapacitating": 0,
    "injuries_reported_not_evident": 0,
    "injuries_no_indication": 0,
    "crash_hour": 0,
    "crash_day_of_week": 0,
    "crash_month": 0,
    "injuries_check": 0
})

# %%
df.to_csv("traffic_accidents_final.csv", index=False)
print("✅ Final dataset saved without missing values.")
# Out:
# ✅ Final dataset saved without missing values.

# %%
missing_rows = df[df.isnull().any(axis=1)]
print(missing_rows)
# Out:
# Empty DataFrame
# Columns: [crash_date, crash_time, AM/PM, lighting_condition, first_crash_type, trafficway_type, alignment, roadway_surface_cond, road_defect, crash_type, intersection_related_i, damage, prim_contributory_cause, num_units, most_severe_injury, injuries_total, injuries_fatal, injuries_incapacitating, injuries_non_incapacitating, injuries_reported_not_evident, injuries_no_indication, crash_hour, crash_day_of_week, crash_month, injuries_check, injury_mismatch]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.to_csv("traffic_accidents_final.csv", index=False)
print("✅ Final dataset saved without missing values.")
# Out:
# ✅ Final dataset saved without missing values.

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...

# %%
import pandas as pd

# Load your dataset
df = pd.read_excel("Copy of traffic_accidents_lastest dit.xlsx")

# Continue your analysis...

# %% [markdown]
# # Traffic accidents Analysis Report
# # (2012-2025)

# %% [markdown]
# # # Introduction

# %% [markdown]
# ## This project examines accident patterns and contributing factors to enhance road safety and reduce future incidents.
# ## It highlights the growing impact of urbanization and increased vehicle use on traffic accidents.

# %% [markdown]
# # # Problem Statement

# %% [markdown]
# ## In recent years, traffic accidents have been increasing, causing not only fatalities and injuries but also financial and social impacts.

# %% [markdown]
# # # Objective

# %% [markdown]
# ## Analyze accident trends by time ( Year, peak Months, Am/Pm).
#
# ## To identify the leading contributory causes of traffic accidents and highlight the most frequent factors.
#
# ## Study environmental factors (weather, lighting, roads) and their impact. and Identify main accident causes (Environment, road).
#
# ## Evaluate the relationship between accident severity and vehicle involvement, focusing on the extent of damages and the number of vehicles.
#
# ## Provide recommendations to improve road safety.

# %% [markdown]
# # # Target Audience

# %% [markdown]
# ## Drivers
# ## Traffic Authorities & Policymakers
# ## Insurance Companies
# ## Transportation & Urban Planners

# %% [markdown]
# # # Dataset Overview

# %% [markdown]
# ## The data was collected to examine various aspects of accidents .
# ## Contains 200k+ traffic accident records. Includes date, time, and location details.
# ## Covers environmental factors and records crash causes, types, and severity.
# ## Tracks injuries and damages for each incident.

# %%
from IPython.display import Image, display

display(Image(filename="1.png"))

# %% [markdown]
# ## overall increasing trend over the years, with a sharp peak in 2018 and 2019 recording the highest accident counts

# %%
from IPython.display import Image, display

display(Image(filename="2.png"))

# %% [markdown]
# ## Accidents peak in October, while February records the fewest incidents, showing higher crash frequency in late year months

# %%
from IPython.display import Image, display

display(Image(filename="3.png"))

# %% [markdown]
# ## PM hours (65%), nearly double the AM , highlighting higher risks in the evening period.

# %%
from IPython.display import Image, display

display(Image(filename="4.png"))

# %% [markdown]
# ## Most accidents were Unable to Determine, followed by driver errors like failing to yield, following too closely, and improper turning.

# %%
from IPython.display import Image, display

display(Image(filename="5.png"))

# %% [markdown]
# ## Most accidents occur in daylight, followed by lighted roads at night, showing traffic volume has a stronger impact than lighting conditions.

# %%
from IPython.display import Image, display

display(Image(filename="6.png"))

# %% [markdown]
# ## Most accidents occur on dry roads, followed by wet conditions, indicating that heavy traffic and driver behavior play a bigger role than weather.

# %%
from IPython.display import Image, display

display(Image(filename="7.png"))

# %% [markdown]
# ## Accidents are most frequent on undivided and four-way roads, showing that intersections and roads without separation pose higher risks for crashes.

# %%
from IPython.display import Image, display

display(Image(filename="8.png"))

# %% [markdown]
# ## Most accidents caused no injuries, while injury-related cases made up a smaller portion.
#
#
# ## Fatal accidents were very rare, representing less than 1% of all reported crashes.

# %%
from IPython.display import Image, display

display(Image(filename="9.png"))

# %% [markdown]
# ## Over 90% of accidents involved two vehicles.
#
# ##  Single-vehicle and multi-vehicle accidents (3 or more) represented a small proportion.

# %%
from IPython.display import Image, display

display(Image(filename="10.png"))

# %% [markdown]
# ## Most accidents (70%) caused damages over $1,500, while only a small share led to moderate or minor losses.

# %% [markdown]
# # # conclusion

# %% [markdown]
# ## Accident rates have risen over time, mainly during evening hours, with most occurring on dry, daylight roads.
# ## Non-fatal but costly crashes were largely caused by driver errors on undivided or four-way roads.

# %% [markdown]
# # # Recommendations

# %% [markdown]
# ## Improve traffic monitoring and safety on high-risk roads, increase driver awareness, and enforce stricter laws to reduce collisions.

# %% [markdown]
# # # Limitations

# %% [markdown]
# ## Data Source – Collected without clear region, limiting generalization.
#
# ## Data Quality – Missing or “Unknown” values in key fields reduce accuracy.
